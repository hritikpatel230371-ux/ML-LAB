# %% [markdown]
# <a href="https://colab.research.google.com/github/hritikpatel230371-ux/ML-LAB/blob/main/Pandas_Exercise_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# use AUTOMOBILE DATASET

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Question 1: From given data set print first and last five rows

# %% [markdown]
# The code cells read the Automobile_data.csv file into a pandas DataFrame and then display the first 5 rows and the last 5 rows of the DataFrame, respectively.

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# Question 2: Clean data and update the CSV file
# Replace all column values which contain ‘?’ and n.a with NaN.

# %% [markdown]
# The code in the next cell reads the Automobile_data.csv file, replaces all  '?' and 'n.a' with NaN (Not a Number) in specified columns ('price', 'stroke', 'horsepower', 'peak-rpm', 'average-mileage'), prints the updated DataFrame, and then saves these changes back to the CSV file.

# %%
df = pd.read_csv("/content/Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})
print (df)
df.to_csv("/content/Automobile_data.csv")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# Question 3: Find the most expensive car company name
# Print most expensive car’s company name and price.

# %% [markdown]
# The code in the  cell wil identifies the most expensive car by filtering the DataFrame where the 'price' column equals its maximum value. It then displays the 'company' and 'price' of this car.

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
df = df [['company','price']][df.price==df['price'].max()]
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# Question 4: Print All Toyota Cars details

# %% [markdown]
# ans-The code in the next cell groups the DataFrame by 'company', then specifically retrieves and displays all rows corresponding to 'toyota' cars.

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
# Out:
#     Unnamed: 0  index company body-style  wheel-base  length engine-type  \
# 48          48     66  toyota  hatchback        95.7   158.7         ohc
# 49          49     67  toyota  hatchback        95.7   158.7         ohc
# 50          50     68  toyota  hatchback        95.7   158.7         ohc
# 51          51     69  toyota      wagon        95.7   169.7         ohc
# 52          52     70  toyota      wagon        95.7   169.7         ohc
# 53          53     71  toyota      wagon        95.7   169.7         ohc
# 54          54     79  toyota      wagon       104.5   187.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 48             four          62               35   5348.0
# 49             four          62               31   6338.0
# 50             four          62               31   6488.0
# 51             four          62               31   6918.0
# 52             four          62               27   7898.0
# ...

# %%
Question 5: Count total cars per company

# %% [markdown]
# The code in the next cell calculates and displays the total count of cars for each unique car company present in the dataset.

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
df['company'].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# mercedes-benz    4
# audi             4
# volkswagen       4
# mitsubishi       4
# chevrolet        3
# jaguar           3
# isuzu            3
# honda            3
# porsche          3
# alfa-romero      3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %%
Question 6: Find each company’s Higesht price car

# %% [markdown]
# The code in the next cell groups the DataFrame by 'company' and then finds the maximum 'price' for each of these companies, displaying the results.

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
car_Manufacturers = df.groupby('company')
priceDf = car_Manufacturers[['company','price']].max()
priceDf
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
Question 7: Find the average mileage of each car making company

# %% [markdown]
# The code in the next cell groups the DataFrame by 'company' and then calculates the mean 'average-mileage' for each company, displaying the results.

# %%
import pandas as pd
df = pd.read_csv("/content/Automobile_data.csv")
car_Manufacturers = df.groupby('company')
mileageDf = car_Manufacturers['average-mileage'].mean()
mileageDf
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %%
Question 8: Sort all cars by Price column

# %% [markdown]
# The code in the next cell sorts the entire DataFrame by the 'price' column (and then by 'horsepower' for ties) in descending order, and displays the top 5 rows of the sorted DataFrame.

# %%
import pandas as pd
carsDf = pd.read_csv("/content/Automobile_data.csv")
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)
carsDf.head(5)
# Out:
#     Unnamed: 0  index        company   body-style  wheel-base  length  \
# 35          35     47  mercedes-benz      hardtop       112.0   199.2
# 11          11     14            bmw        sedan       103.5   193.8
# 34          34     46  mercedes-benz        sedan       120.9   208.1
# 46          46     62        porsche  convertible        89.5   168.9
# 12          12     15            bmw        sedan       110.0   197.0
#
#    engine-type num-of-cylinders  horsepower  average-mileage    price
# 35        ohcv            eight         184               14  45400.0
# 11         ohc              six         182               16  41315.0
# 34        ohcv            eight         184               14  40960.0
# 46        ohcf              six         207               17  37028.0
# 12         ohc              six         182               15  36880.0

# %%
import pandas as pd

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

df_german = pd.DataFrame(GermanCars)
df_japanese = pd.DataFrame(japaneseCars)

carsDf = pd.concat([df_german, df_japanese], keys=['GermanCars', 'JapaneseCars'])
print(carsDf)
# Out:
#                     Company   Price
# GermanCars   0         Ford   23845
#              1     Mercedes  171995
#              2          BMV  135925
#              3         Audi   71400
# JapaneseCars 0       Toyota   29995
#              1        Honda   23600
#              2       Nissan   61500
#              3  Mitsubishi    58900

# %% [markdown]
# The following code creates two pandas DataFrames from provided dictionaries (GermanCars and JapaneseCars) and then concatenates them into a single DataFrame. Keys ('GermanCars', 'JapaneseCars') are used to create a hierarchical index, indicating the origin of each car entry.

# %%
import pandas as pd
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)

# %%
#Question 10: Merge two data frames using following condition
   # Create two data frames using following two Dicts, Merge two data frames, and append second data frame as a new column to first data frame.

Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %% [markdown]
#  The code in the next cell creates two pandas DataFrames, carPriceDf and carsHorsepowerDf, from given dictionaries. It then merges these two DataFrames into carsDf based on the common 'Company' column, effectively appending the horsepower information as a new column to the car price data.

# %%
import pandas as pd
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
carPriceDf = pd.DataFrame.from_dict(Car_Price)
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)
carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
